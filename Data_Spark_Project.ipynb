# %% [markdown]
# Importing Libraries

# %%
import missingno as msno
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pymysql
import mysql.connector
import numpy as np

# %% [markdown]
# Customers Table

# %%
file_path = 'C:/Users/Rahul/Downloads/Customers.csv'
df_customers = pd.read_csv(file_path)
df_customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Dušková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
df_customers.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
#Dropping useless columns
df_customers.drop(["State Code","Zip Code"],axis=1,inplace=True)
df_customers
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Dušková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State        Country      Continent    Birthday
# 0        South Australia      Australia      Australia  07-03-1939
# ...

# %%
# Remove duplicate rows
df_customers.drop_duplicates(inplace=True)
df_customers
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Dušková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State        Country      Continent    Birthday
# 0        South Australia      Australia      Australia  07-03-1939
# ...

# %%
# Convert Birthday column to datetime
df_customers['Birthday'] = df_customers['Birthday'].str.replace('-', '/')
df_customers['Birthday'] = pd.to_datetime(df_customers['Birthday'], format='%m/%d/%Y')
df_customers
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Dušková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State        Country      Continent   Birthday
# 0        South Australia      Australia      Australia 1939-07-03
# ...

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State        15266 non-null  object
#  5   Country      15266 non-null  object
#  6   Continent    15266 non-null  object
#  7   Birthday     15266 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 954.3+ KB

# %%
# Save the cleaned dataset to a new CSV file
Output_path = "C:/Users/Rahul/Documents/Data Science Projects/Dataspark Project/Cleaned_Customers.csv"
df_customers.to_csv(Output_path, index=False)

# %% [markdown]
# Exchange Rates Table

# %%
file_path = 'C:/Users/Rahul/Downloads/Exchange_Rates.csv'
df_exchange_rates = pd.read_csv(file_path)
df_exchange_rates
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df_exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
df_exchange_rates.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
# Convert 'Date' column to datetime objects
df_exchange_rates['Date'] = pd.to_datetime(df_exchange_rates['Date'])
df_exchange_rates
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df_exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
# Save the cleaned dataset to a new CSV file
Output_path = "C:/Users/Rahul/Documents/Data Science Projects/Dataspark Project/Cleaned_Exchange_Rates.csv"
df_exchange_rates.to_csv(Output_path, index=False)

# %% [markdown]
# Products Table

# %%
file_path = 'C:/Users/Rahul/Downloads/Products.csv'
df_products = pd.read_csv(file_path)
df_products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
df_products.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
df_products.drop(["SubcategoryKey"],axis=1,inplace=True)
df_products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD              Subcategory  \
# ...

# %%
# Data Type Conversion
# Convert columns to the appropriate data types if needed
# Example: Convert 'Unit Cost USD' and 'Unit Price USD' to numeric type
df_products['Unit Cost USD'] = df_products['Unit Cost USD'].str.replace('$', '').str.replace(",", "").str.strip().astype(float)
df_products['Unit Price USD'] = df_products['Unit Price USD'].str.replace('$', '').str.replace(",", "").str.strip().astype(float)
df_products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD              Subcategory  \
# ...

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   float64
#  5   Unit Price USD  2517 non-null   float64
#  6   Subcategory     2517 non-null   object
#  7   CategoryKey     2517 non-null   int64
#  8   Category        2517 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 177.1+ KB

# %%
# Save the cleaned dataset to a new CSV file
Output_path = "C:/Users/Rahul/Documents/Data Science Projects/Dataspark Project/Cleaned_Products.csv"
df_products.to_csv(Output_path, index=False)

# %% [markdown]
# Sales Table

# %%
file_path = 'C:/Users/Rahul/Downloads/Sales.csv'
df_sales = pd.read_csv(file_path)
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
df_sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
# Convert 'Order Date' column to datetime objects
df_sales['Order Date'] = pd.to_datetime(df_sales['Order Date'])
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01           NaN       265598
# 1            366001          1 2016-01-01     1/13/2016      1269051
# 2            366001          2 2016-01-01     1/13/2016      1269051
# 3            366002          1 2016-01-01     1/12/2016       266019
# 4            366002          2 2016-01-01     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20           NaN      1216913
# 62880       2243031          1 2021-02-20     2/24/2021       511229
# 62881       2243032          1 2021-02-20     2/23/2021       331277
# 62882       2243032          2 2021-02-20     2/23/2021       331277
# 62883       2243032          3 2021-02-20     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df_sales['Delivery Date'] = pd.to_datetime(df_sales['Delivery Date'], format="%m/%d/%Y", errors='coerce').dt.date
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01           NaT       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20           NaT      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
# fill the missing values
df_sales["Delivery Date"]=df_sales["Delivery Date"].fillna(0)
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01             0       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20             0      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df_sales['Delivery Date'] = df_sales['Delivery Date'].replace(0, '1970-01-01')  # Replace 0 with a valid default date
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01    1970-01-01       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20    1970-01-01      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  datetime64[ns]
#  3   Delivery Date  62884 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: datetime64[ns](1), int64(6), object(2)
# memory usage: 4.3+ MB

# %%
# Save the cleaned dataset to a new CSV file
Output_path = "C:/Users/Rahul/Documents/Data Science Projects/Dataspark Project/Cleaned_Sales.csv"
df_sales.to_csv(Output_path, index=False)

# %% [markdown]
# Stores Table

# %%
file_path = 'C:/Users/Rahul/Downloads/Stores.csv'
df_stores = pd.read_csv(file_path)
df_stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df_stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
# Convert 'Open Date' to datetime objects
df_stores['Open Date'] = pd.to_datetime(df_stores['Open Date'])
df_stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
df_stores = df_stores[~(df_stores['Country'] == 'Online')]
df_stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 61        62  United States                  South Dakota         1120.0
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, 0 to 65
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       66 non-null     int64
#  1   Country        66 non-null     object
#  2   State          66 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      66 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 3.1+ KB

# %%
df_stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
# Save the cleaned dataset to a new CSV file
Output_path = "C:/Users/Rahul/Documents/Data Science Projects/Dataspark Project/Cleaned_Stores.csv"
df_stores.to_csv(Output_path, index=False)

# %% [markdown]
# SQL Database Connection

# %% [markdown]
# Database Creation

# %%
import mysql.connector

try:
    # Connect to MySQL
    mydb = mysql.connector.connect(
        host="localhost",
        user="root",
        password="12345",  # Replace with actual password
    )
    my_cursor = mydb.cursor()

    # Create database
    my_cursor.execute("CREATE DATABASE IF NOT EXISTS data_spark")
    print("Database created successfully")

except mysql.connector.Error as err:
    print(f"Error: {err}")
# Out:
# Database created successfully

# %% [markdown]
# Customers Table Creation

# %%
import mysql.connector

try:
    # Initialize connection
    mydb = mysql.connector.connect(
        host="localhost",
        user="root",
        password="12345",  # Replace with actual password
        database="data_spark"
    )
    my_cursor = mydb.cursor()

    # Create table
    my_cursor.execute('''
        CREATE TABLE IF NOT EXISTS customers(
            CustomerKey INT(64),
            Gender VARCHAR(255),
            Name VARCHAR(255),
            City VARCHAR(255),
            State VARCHAR(255),
            Country VARCHAR(255),
            Continent VARCHAR(255),
            Birthday DATE
        )
    ''')
    print("Table created successfully")
except mysql.connector.Error as err:
    print(f"Error: {err}")
finally:
    # Close cursor and connection
    if my_cursor:
        my_cursor.close()
    if mydb.is_connected():
        mydb.close()
# Out:
# Table created successfully

# %% [markdown]
# Customers Table Values Insertion

# %%
import mysql.connector
import pandas as pd

# Load cleaned dataset
df_customers = pd.read_csv("C:/Users/Rahul/Documents/Data Science Projects/Dataspark Project/Cleaned_Customers.csv", encoding = 'latin-1')

# Connect to MySQL
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345",  # Replace with your MySQL password
    database="data_spark"
)
my_cursor = mydb.cursor()

# insert values into customer table
insert_query='''INSERT INTO customers(
                  CustomerKey,
                  Gender,
                  Name,
                  City,
                  State,
                  Country,
                  Continent,
                  Birthday)
                  VALUES(%s,%s,%s,%s,%s,%s,%s,%s)'''
data=df_customers.values.tolist()
batch_size = 1000  # Adjust this value as needed

for i in range(0, len(data), batch_size):
    batch_data = data[i:i + batch_size]
    try:
        # Performing batch insert with executemany()
        my_cursor.executemany(insert_query, batch_data)
        mydb.commit()
    except mysql.connector.Error as err:
        if err.errno == mysql.connector.errorcode.CR_SERVER_LOST or err.errno == mysql.connector.errorcode.CR_SERVER_GONE_ERROR:
            reconnect()
            my_cursor.executemany(insert_query, batch_data)
            mydb.commit()
print("Inserted successfully")
# Out:
# Inserted successfully

# %% [markdown]
# Exchange Rates Table Creation

# %%
my_cursor.execute('''CREATE TABLE IF NOT EXISTS exchange_rates(
                  Date DATE,
                  Currency_Code VARCHAR(255),
                  Exchange FLOAT
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %% [markdown]
# Exchange Rates Table Value Insertion

# %%
import mysql.connector
import pandas as pd

# Load cleaned dataset
df_exchange_rates = pd.read_csv("C:/Users/Rahul/Documents/Data Science Projects/Dataspark Project/Cleaned_Exchange_Rates.csv")

# Connect to MySQL
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345",  # Replace with your MySQL password
    database="data_spark"
)
my_cursor = mydb.cursor()

# insert values into exchange_rates table
insert_query ='''INSERT INTO exchange_rates(
                  Date,
                  Currency_Code,
                  Exchange)
                  VALUES (%s, %s, %s)'''
data=df_exchange_rates.values.tolist()
batch_size = 1000  # Adjust this value as needed

for i in range(0, len(data), batch_size):
    batch_data = data[i:i + batch_size]
    try:
        # Performing batch insert with executemany()
        my_cursor.executemany(insert_query, batch_data)
        mydb.commit()
    except mysql.connector.Error as err:
        if err.errno == mysql.connector.errorcode.CR_SERVER_LOST or err.errno == mysql.connector.errorcode.CR_SERVER_GONE_ERROR:
            reconnect()
            my_cursor.executemany(insert_query, batch_data)
            mydb.commit()
print("Inserted successfully")
# Out:
# Inserted successfully

# %% [markdown]
# Products Table Creation

# %%
my_cursor.execute('''CREATE TABLE IF NOT EXISTS products(
                  ProductKey INT(64),
                  Product_Name VARCHAR(255),
                  Brand VARCHAR(255),
                  Color VARCHAR(255),
                  Unit_Cost_USD FLOAT,
                  Unit_Price_USD FLOAT,
                  Subcategory VARCHAR(255),
                  CategoryKey INT(64),
                  Category VARCHAR(255)
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %% [markdown]
# Products Table Values Insertion

# %%
import mysql.connector
import pandas as pd

# Load cleaned dataset
df_products = pd.read_csv("C:/Users/Rahul/Documents/Data Science Projects/Dataspark Project/Cleaned_Products.csv")

# Connect to MySQL
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345",  # Replace with your MySQL password
    database="data_spark"
)
my_cursor = mydb.cursor()

# insert values into products table
insert_query ='''INSERT INTO products(
                  ProductKey,
                  Product_Name,
                  Brand,
                  Color,
                  Unit_Cost_USD,
                  Unit_Price_USD,
                  Subcategory,
                  CategoryKey,
                  Category)
                  VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s)'''
data=df_products.values.tolist()
batch_size = 1000  # Adjust this value as needed

for i in range(0, len(data), batch_size):
    batch_data = data[i:i + batch_size]
    try:
        # Performing batch insert with executemany()
        my_cursor.executemany(insert_query, batch_data)
        mydb.commit()
    except mysql.connector.Error as err:
        if err.errno == mysql.connector.errorcode.CR_SERVER_LOST or err.errno == mysql.connector.errorcode.CR_SERVER_GONE_ERROR:
            reconnect()
            my_cursor.executemany(insert_query, batch_data)
            mydb.commit()
print("Inserted successfully")
# Out:
# Inserted successfully

# %% [markdown]
# Sales Table Creation

# %%
# Connect to MySQL
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345",  # Replace with your MySQL password
    database="data_spark"
)
my_cursor = mydb.cursor()

my_cursor.execute('''CREATE TABLE IF NOT EXISTS sales(
                  Order_Number INT(64),
                  Line_Item INT(64),
                  Order_Date DATE,
                  Delivery_Date DATE,
                  CustomerKey INT(64),
                  StoreKey INT(64),
                  ProductKey INT(64),
                  Quantity INT(64),
                  Currency_Code VARCHAR(255)
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %% [markdown]
# Sales Table Values Insertion

# %%
import mysql.connector
import pandas as pd

# Load cleaned dataset
df_sales = pd.read_csv("C:/Users/Rahul/Documents/Data Science Projects/Dataspark Project/Cleaned_Sales.csv")

# Connect to MySQL
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345",  # Replace with your MySQL password
    database="data_spark"
)
my_cursor = mydb.cursor()

#insert values into sales table
insert_query ='''INSERT INTO sales(
                  Order_Number,
                  Line_Item,
                  Order_Date,
                  Delivery_Date,
                  CustomerKey,
                  StoreKey,
                  ProductKey,
                  Quantity,
                  Currency_Code)
                  VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s)'''
data=df_sales.values.tolist()
batch_size = 1000  # Adjust this value as needed

for i in range(0, len(data), batch_size):
    batch_data = data[i:i + batch_size]
    try:
        # Performing batch insert with executemany()
        my_cursor.executemany(insert_query, batch_data)
        mydb.commit()
    except mysql.connector.Error as err:
        if err.errno == mysql.connector.errorcode.CR_SERVER_LOST or err.errno == mysql.connector.errorcode.CR_SERVER_GONE_ERROR:
            reconnect()
            my_cursor.executemany(insert_query, batch_data)
            mydb.commit()
print("Inserted successfully")
# Out:
# Inserted successfully

# %% [markdown]
# Stores Table Creation

# %%
my_cursor.execute('''CREATE TABLE IF NOT EXISTS stores(
                  StoreKey INT,
                  Country VARCHAR(255),
                  State VARCHAR(255),
                  Square_Meters FLOAT,
                  Open_Date DATE
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
import mysql.connector
import pandas as pd

# Load cleaned dataset
df_stores = pd.read_csv("C:/Users/Rahul/Documents/Data Science Projects/Dataspark Project/Cleaned_Stores.csv")

# Connect to MySQL
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="12345",  # Replace with your MySQL password
    database="data_spark"
)
my_cursor = mydb.cursor()

#insert values into Store table
insert_query ='''INSERT INTO stores(
                  StoreKey,
                  Country,
                  State,
                  Square_Meters,
                  Open_Date)
                  VALUES (%s, %s, %s, %s, %s)'''
data=df_stores.values.tolist()
batch_size = 1000  # Adjust this value as needed

for i in range(0, len(data), batch_size):
    batch_data = data[i:i + batch_size]
    try:
        # Performing batch insert with executemany()
        my_cursor.executemany(insert_query, batch_data)
        mydb.commit()
    except mysql.connector.Error as err:
        if err.errno == mysql.connector.errorcode.CR_SERVER_LOST or err.errno == mysql.connector.errorcode.CR_SERVER_GONE_ERROR:
            reconnect()
            my_cursor.executemany(insert_query, batch_data)
            mydb.commit()
print("Inserted successfully")
# Out:
# Inserted successfully
